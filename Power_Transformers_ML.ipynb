# %%
import numpy as np, pandas as pd, seaborn as sns

log_normal = np.random.lognormal(2,1,1000)
exponential = np.random.exponential(1,1000)
pareto = np.random.pareto(3,1000)
power = np.random.power(5,1000)
uniform = np.random.uniform(-1,0,1000)
df = pd.DataFrame({"log_normal":log_normal,"exponential":exponential,"pareto":pareto,"power":power,"uniform":uniform})

# %%
import sklearn
from sklearn.model_selection import train_test_split
dfTrain,dfTest= train_test_split (df, test_size=0.20,random_state=32)

# %%
from sklearn.preprocessing import PowerTransformer

pt=PowerTransformer()

YeoDF1= pd.DataFrame(pt.fit_transform(dfTrain), columns=dfTrain.columns, index=dfTrain.index)

# %%
YeoDF1
# Out:
#      log_normal  exponential    pareto     power   uniform
# 799   -1.051251    -1.627120  1.275316 -0.845181 -1.615107
# 471    1.222575     0.817588 -0.190746  0.212346  0.219759
# 242   -0.123149     1.408271 -1.410064  0.860571  0.480310
# 704    1.372079     0.195623  0.740909 -0.480681 -1.470949
# 839   -0.503410     0.203932 -0.017285  1.367584  1.389106
# ..          ...          ...       ...       ...       ...
# 892    1.024683    -0.954921  1.561418 -1.342330 -1.280369
# 310    0.196804     1.728337 -1.227455 -0.233186  1.008395
# 901    0.458635     0.301155 -0.294018  1.572681 -1.669214
# 555   -2.141251    -0.637368  1.193879 -1.293010  0.799665
# 727   -0.532209    -0.977366  0.555100 -1.640391  0.554502
#
# [800 rows x 5 columns]

# %%
sns.histplot(df['exponential'],kde=True)
# Out:
# <Axes: xlabel='exponential', ylabel='Count'>

# %%
sns.histplot(YeoDF1['exponential'],kde=True)
# Out:
# <Axes: xlabel='exponential', ylabel='Count'>

# %%
bpt=PowerTransformer(method='box-cox')

BoxDF2= pd.DataFrame(bpt.fit_transform(dfTrain[['exponential']]), columns=['exponential'], index=dfTrain.index)

BoxDF2
# Out:
#      exponential
# 799    -1.882484
# 471     0.734293
# 242     1.333312
# 704     0.194149
# 839     0.201082
# ..           ...
# 892    -0.818418
# 310     1.727462
# 901     0.282533
# 555    -0.512304
# 727    -0.841913
#
# [800 rows x 1 columns]

# %%
sns.histplot(BoxDF2['exponential'],kde=True)
# Out:
# <Axes: xlabel='exponential', ylabel='Count'>
